# %%
import pandas as pd

# %%
df = pd.read_csv("advertisement .csv")
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
columns = ["daily_time_spent_on_site","age","area_income","daily_internet_usage","ad_topic_line","city","male","country","timestamp","clicked_on_ad"]

# %%
df.columns = columns

# %%
df.head()
# Out:
#    daily_time_spent_on_site  age  area_income  daily_internet_usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            ad_topic_line            city  male     country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              timestamp  clicked_on_ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
a = df["ad_topic_line"][0:100]
b = df["ad_topic_line"][100:200]
c = df["ad_topic_line"][200:300]
d = df["ad_topic_line"][300:400]
e = df["ad_topic_line"][400:500]
f = df["ad_topic_line"][500:600]
g = df["ad_topic_line"][600:700]
h = df["ad_topic_line"][700:800]
ı = df["ad_topic_line"][800:900]
i = df["ad_topic_line"][900: 1000]

# %%
df["ad_topic_line"][0:100] = d
df["ad_topic_line"][100:200] = f
df["ad_topic_line"][200:300] = c
df["ad_topic_line"][300:400] = a
df["ad_topic_line"][400:500] = e
df["ad_topic_line"][500:600] = g
df["ad_topic_line"][600:700] = ı
df["ad_topic_line"][700:800] = b
df["ad_topic_line"][800:900] = i
df["ad_topic_line"][900:1000] = h
# Out:
# <ipython-input-7-2c3c1b53072a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ad_topic_line"][0:100] = d
# <ipython-input-7-2c3c1b53072a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ad_topic_line"][100:200] = f
# <ipython-input-7-2c3c1b53072a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ad_topic_line"][200:300] = c
# <ipython-input-7-2c3c1b53072a>:4: SettingWithCopyWarning:
# ...

# %%
a = df["city"][0:100]
b = df["city"][100:200]
c = df["city"][200:300]
d = df["city"][300:400]
e = df["city"][400:500]
f = df["city"][500:600]
g = df["city"][600:700]
h = df["city"][700:800]
ı = df["city"][800:900]
i = df["city"][900: 1000]

# %%
df["city"][0:100] = d
df["city"][100:200] = f
df["city"][200:300] = c
df["city"][300:400] = a
df["city"][400:500] = e
df["city"][500:600] = g
df["city"][600:700] = ı
df["city"][700:800] = b
df["city"][800:900] = i
df["city"][900:1000] = h
# Out:
# <ipython-input-9-d95ea9b404d7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["city"][0:100] = d
# <ipython-input-9-d95ea9b404d7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["city"][100:200] = f
# <ipython-input-9-d95ea9b404d7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["city"][200:300] = c
# <ipython-input-9-d95ea9b404d7>:4: SettingWithCopyWarning:
# ...

# %%
a = df["country"][0:100]
b = df["country"][100:200]
c = df["country"][200:300]
d = df["country"][300:400]
e = df["country"][400:500]
f = df["country"][500:600]
g = df["country"][600:700]
h = df["country"][700:800]
ı = df["country"][800:900]
i = df["country"][900: 1000]

# %%
df["country"][0:100] = d
df["country"][100:200] = f
df["country"][200:300] = c
df["country"][300:400] = a
df["country"][400:500] = e
df["country"][500:600] = g
df["country"][600:700] = ı
df["country"][700:800] = b
df["country"][800:900] = i
df["country"][900:1000] = h
# Out:
# <ipython-input-11-54e414d7da8a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["country"][0:100] = d
# <ipython-input-11-54e414d7da8a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["country"][100:200] = f
# <ipython-input-11-54e414d7da8a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["country"][200:300] = c
# <ipython-input-11-54e414d7da8a>:4: SettingWithCopyWarning:
# ...

# %%
df.to_csv("alican.csv", index_label=False)

# %%
ayşenur = pd.read_csv("alican.csv")
ayşenur.head()
# Out:
#    daily_time_spent_on_site  age  area_income  daily_internet_usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                                 ad_topic_line              city  male  \
# 0           Mandatory 3rdgeneration moderator       Cynthiaside     0
# 1        Enterprise-wide foreground emulation         Port Juan     1
# 2  Customer-focused incremental system engine      Michellefort     0
# 3          Right-sized multi-tasking solution  Port Angelamouth     1
# 4       Vision-oriented optimizing middleware      Jessicahaven     0
#
#                          country            timestamp  clicked_on_ad
# ...
