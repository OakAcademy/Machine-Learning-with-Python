# %% [markdown]
# # K Nearest Neighbors(KNN) with Python
#
#
# You have been given a classified data set from a company! They hid the feature column names but gave you the data and target classes.
#
# We will try to use KNN to create a model that directly predicts a class for a new data point based on features.
#
# Let's grab and use it!

# %% [markdown]
# ## Episode 1: Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Episode 2: Get the Data
#
# **Set index_col=0 to use the first column as the index.**

# %%
df = pd.read_csv("Classified_Data.csv",index_col=0)

# %%
df.head()
# Out:
#         ASC       TRA       ACA       YKC       HLC       SKA       KFK  \
# 0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# 3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128  1.409708
# 4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727  1.115596
#
#         WAS       AGE       XPS  TARGET_CLASS
# 0  0.643798  0.879422  1.231409             1
# 1  1.013546  0.621552  1.492702             0
# 2  1.154483  0.957877  1.285597             0
# 3  1.380003  1.522692  1.153093             1
# 4  0.646691  1.463812  1.419167             1

# %% [markdown]
# ## Episode 3: Standardize the Variables
#
# The scale of the variables is important as the KNN classifier predicts the class of a particular test observation by identifying the observations closest to it. Any variable on a large scale will have a much greater effect on the distance between observations and therefore on the KNN classifier than variables on a small scale.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df.drop('TARGET_CLASS',axis=1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(df.drop('TARGET_CLASS',axis=1))

# %%
df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feat.head()
# Out:
#         ASC       TRA       ACA       YKC       HLC       SKA       KFK  \
# 0 -0.123542  0.185907 -0.913431  0.319629 -1.033637 -2.308375 -0.798951
# 1 -1.084836 -0.430348 -1.025313  0.625388 -0.444847 -1.152706 -1.129797
# 2 -0.788702  0.339318  0.301511  0.755873  2.031693 -0.870156  2.599818
# 3  0.982841  1.060193 -0.621399  0.625299  0.452820 -0.267220  1.750208
# 4  1.139275 -0.640392 -0.709819 -0.057175  0.822886 -0.936773  0.596782
#
#         WAS       AGE       XPS
# 0 -1.482368 -0.949719 -0.643314
# 1 -0.202240 -1.828051  0.636759
# 2  0.285707 -0.682494 -0.377850
# 3  1.066491  1.241325 -1.026987
# 4 -1.472352  1.040772  0.276510

# %% [markdown]
# ## Episode 4: Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_features,df['TARGET_CLASS'], test_size=0.30, random_state = 101)

# %% [markdown]
# ## Episode 5: Using KNN
#
# Note that we're trying to build a model to predict whether someone will have a TARGET CLASS. We will start with K = 1.

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = knn.predict(X_test)

# %% [markdown]
# ## Episode 6: Predictions and Evaluations
#
# Let's evaluate our KNN model!

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[151   8]
#  [ 15 126]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       159
#            1       0.94      0.89      0.92       141
#
#     accuracy                           0.92       300
#    macro avg       0.92      0.92      0.92       300
# weighted avg       0.92      0.92      0.92       300

# %% [markdown]
# ## Episode 7: Choosing a K Value
#
# Let's go ahead and use the elbow method to pick a good K Value:

# %%
error_rate = []

# Will take some time
for i in range(1,40):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# Here we can see that after about K> 17 the error rate tends to hover around 0.06-0.05, with this let's retrain the model and check the classification report!

# %%
# FIRST A QUICK COMPARISON TO OUR ORIGINAL K=1
knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print('WITH K=1')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# WITH K=1
#
#
# [[151   8]
#  [ 15 126]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       159
#            1       0.94      0.89      0.92       141
#
#     accuracy                           0.92       300
#    macro avg       0.92      0.92      0.92       300
# weighted avg       0.92      0.92      0.92       300

# %%
# NOW WITH K=17
knn = KNeighborsClassifier(n_neighbors=17)

knn.fit(X_train,y_train)
pred = knn.predict(X_test)

print('WITH K=17')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# WITH K=17
#
#
# [[153   6]
#  [  9 132]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       159
#            1       0.96      0.94      0.95       141
#
#     accuracy                           0.95       300
#    macro avg       0.95      0.95      0.95       300
# weighted avg       0.95      0.95      0.95       300

# %% [markdown]
# # Great job!
#
# By adjusting it to a better K value, we were able to get a little more performance from our model!
